# %%
pip install boto3 python-dotenv PyPDF2
# Out:
# Requirement already satisfied: boto3 in ./.venv/lib/python3.10/site-packages (1.35.33)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: PyPDF2 in ./.venv/lib/python3.10/site-packages (3.0.1)
# Requirement already satisfied: botocore<1.36.0,>=1.35.33 in ./.venv/lib/python3.10/site-packages (from boto3) (1.35.33)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.venv/lib/python3.10/site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./.venv/lib/python3.10/site-packages (from boto3) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.venv/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.33->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./.venv/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.33->boto3) (2.2.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.33->boto3) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import boto3
import json
from dotenv import load_dotenv
import PyPDF2

# Carregar variáveis de ambiente do arquivo .env
load_dotenv()

# Configuração do modelo Bedrock
class Settings:
    llm = boto3.client(
        'bedrock',
        region_name=os.getenv('AWS_REGION'),
        aws_access_key_id=os.getenv('AWS_ACCESS_KEY'),
        aws_secret_access_key=os.getenv('AWS_SECRET_KEY')
    )

def extrair_texto_pdf(pdf_path):
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        texto = ""
        for page in reader.pages:
            texto += page.extract_text() + "\n"
    return texto.strip()

def gerar_quiz_a_partir_pdf(pdf_content):
    prompt = (
        "Baseado no seguinte conteúdo de PDF, crie um quiz com 5 perguntas de múltipla escolha, "
        "cada uma com 4 opções de resposta. Inclua a resposta correta para cada pergunta:\n\n"
        f"{pdf_content}\n\n"
        "Formato de resposta: JSON."
    )

    try:
        response = Settings.llm.invoke_model(
            modelId='meta.llama3-1-70b-instruct-v1:0',  # ID do modelo que você deseja usar
            body={
                "prompt": prompt,
                "maxTokens": 300,
                "temperature": 0.1,  # Ajuste a temperatura conforme necessário
                "contextSize": 128   # Ajuste o tamanho do contexto
            }
        )
        
        return json.loads(response['body'])  # Retorna a resposta como dicionário
    except Exception as e:
        print(f"Ocorreu um erro: {e}")
        return None

def main():
    # Caminho para o arquivo PDF
    #pdf_path = "caminho/para/seu/arquivo.pdf"  # Substitua pelo caminho do seu PDF
    pdf_path = "pdf.pdf"
    
    # Extrair o conteúdo do PDF
    pdf_content = extrair_texto_pdf(pdf_path)
    
    # Gerar o quiz
    quiz = gerar_quiz_a_partir_pdf(pdf_content)
    
    if quiz:
        print("Quiz gerado:", json.dumps(quiz, indent=2))

if __name__ == "__main__":
    main()
# Out:
# Ocorreu um erro: 'Bedrock' object has no attribute 'invoke_model'

# %%
import os
import boto3
import json
from dotenv import load_dotenv
import PyPDF2

# Carregar variáveis de ambiente do arquivo .env
load_dotenv()

# Configuração do modelo Bedrock
class Settings:
    llm = boto3.client(
        'bedrock',
        region_name=os.getenv('AWS_REGION'),
        aws_access_key_id=os.getenv('AWS_ACCESS_KEY'),
        aws_secret_access_key=os.getenv('AWS_SECRET_KEY')
    )

def extrair_texto_pdf(pdf_path):
    """Extrai o texto de um arquivo PDF."""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        texto = ""
        for page in reader.pages:
            texto += page.extract_text() + "\n"
    return texto.strip()

def gerar_quiz_a_partir_pdf(pdf_content):
    """Gera um quiz a partir do conteúdo do PDF usando Bedrock."""
    prompt = (
        "Baseado no seguinte conteúdo de PDF, crie um quiz com 5 perguntas de múltipla escolha, "
        "cada uma com 4 opções de resposta. Inclua a resposta correta para cada pergunta:\n\n"
        f"{pdf_content}\n\n"
        "Formato de resposta: JSON."
    )

    try:
        response = Settings.llm.invoke_endpoint(
            EndpointName='meta.llama3-1-70b-instruct-v1:0',  # Nome do endpoint
            Body=json.dumps({
                "prompt": prompt,
                "maxTokens": 300,
                "temperature": 0.1,  # Ajuste conforme necessário
                "contextSize": 128
            }),
            ContentType='application/json'
        )
        
        return json.loads(response['Body'].read())  # Retorna a resposta como dicionário
    except Exception as e:
        print(f"Ocorreu um erro: {e}")
        return None

def main():
    # Caminho para o arquivo PDF
    pdf_path = "pdf.pdf"  # Substitua pelo caminho do seu PDF
    
    # Extrair o conteúdo do PDF
    pdf_content = extrair_texto_pdf(pdf_path)
    
    # Gerar o quiz
    quiz = gerar_quiz_a_partir_pdf(pdf_content)
    
    if quiz:
        print("Quiz gerado:", json.dumps(quiz, indent=2))

if __name__ == "__main__":
    main()
# Out:
# Ocorreu um erro: 'Bedrock' object has no attribute 'invoke_endpoint'

# %%
# !pip install bedrock
# Out:
# Collecting bedrock
#   Downloading bedrock-0.1.0.dev10-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting matplotlib==2.2.2 (from bedrock)
#   Downloading matplotlib-2.2.2.tar.gz (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 2.5 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting nltk==3.2.5 (from bedrock)
#   Downloading nltk-3.2.5.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 1.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas==0.22.0 (from bedrock)
#   Downloading pandas-0.22.0.tar.gz (11.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 2.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [86 lines of output]
#       Ignoring numpy: markers 'python_version == "3.5"' don't match your environment
#       Ignoring numpy: markers 'python_version == "3.6"' don't match your environment
#       Collecting wheel
#         Downloading wheel-0.44.0-py3-none-any.whl.metadata (2.3 kB)
#       Collecting setuptools
#         Using cached setuptools-75.1.0-py3-none-any.whl.metadata (6.9 kB)
#       Collecting Cython
#         Downloading Cython-3.0.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
#       Collecting numpy==1.13.1
#         Downloading numpy-1.13.1.zip (5.0 MB)
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.0 MB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.0 MB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.0 MB ? eta -:--:--
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/5.0 MB ? eta -:--:--
#            ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/5.0 MB ? eta -:--:--
#            ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/5.0 MB ? eta -:--:--
#            ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/5.0 MB 550.7 kB/s eta 0:00:09
#            ━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.5/5.0 MB 550.7 kB/s eta 0:00:09
#            ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.8/5.0 MB 602.7 kB/s eta 0:00:08
#            ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.8/5.0 MB 602.7 kB/s eta 0:00:08
#            ━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/5.0 MB 647.2 kB/s eta 0:00:07
#            ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/5.0 MB 685.7 kB/s eta 0:00:06
#            ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/5.0 MB 685.7 kB/s eta 0:00:06
#            ━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/5.0 MB 699.3 kB/s eta 0:00:05
#            ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/5.0 MB 737.5 kB/s eta 0:00:05
#            ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 2.1/5.0 MB 772.2 kB/s eta 0:00:04
#            ━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━ 2.1/5.0 MB 772.2 kB/s eta 0:00:04
#            ━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━ 2.4/5.0 MB 804.6 kB/s eta 0:00:04
#            ━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━ 2.6/5.0 MB 834.8 kB/s eta 0:00:03
#            ━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━ 2.9/5.0 MB 860.2 kB/s eta 0:00:03
#            ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 3.1/5.0 MB 888.0 kB/s eta 0:00:03
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━ 3.4/5.0 MB 916.4 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━ 3.9/5.0 MB 968.9 kB/s eta 0:00:02
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━ 4.2/5.0 MB 993.6 kB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━ 4.5/5.0 MB 1.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 4.7/5.0 MB 1.0 MB/s eta 0:00:01
#            ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 1.1 MB/s eta 0:00:00
#         Installing build dependencies: started
#         Installing build dependencies: finished with status 'done'
#         Getting requirements to build wheel: started
#         Getting requirements to build wheel: finished with status 'done'
#         Preparing metadata (pyproject.toml): started
#         Preparing metadata (pyproject.toml): finished with status 'error'
#         error: subprocess-exited-with-error
#
#         × Preparing metadata (pyproject.toml) did not run successfully.
#         │ exit code: 1
#         ╰─> [28 lines of output]
#             Running from numpy source directory.
#             <string>:367: UserWarning: Unrecognized setuptools command, proceeding with generating Cython sources and expanding templates
#             /tmp/pip-install-ldt4wizz/numpy_aa6fe1d226f84e6bb986f44165aa0ae6/numpy/distutils/misc_util.py:469: SyntaxWarning: "is" with a literal. Did you mean "=="?
#               return is_string(s) and ('*' in s or '?' is s)
#             Traceback (most recent call last):
#               File "/home/alysson/workspace/llama3.2/.venv/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#                 main()
#               File "/home/alysson/workspace/llama3.2/.venv/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#                 json_out['return_val'] = hook(**hook_input['kwargs'])
#               File "/home/alysson/workspace/llama3.2/.venv/lib/python3.10/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 149, in prepare_metadata_for_build_wheel
#                 return hook(metadata_directory, config_settings)
#               File "/tmp/pip-build-env-qsadcm4p/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 373, in prepare_metadata_for_build_wheel
#                 self.run_setup()
#               File "/tmp/pip-build-env-qsadcm4p/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 503, in run_setup
#                 super().run_setup(setup_script=setup_script)
#               File "/tmp/pip-build-env-qsadcm4p/overlay/lib/python3.10/site-packages/setuptools/build_meta.py", line 318, in run_setup
#                 exec(code, locals())
#               File "<string>", line 392, in <module>
#               File "<string>", line 371, in setup_package
#               File "/tmp/pip-install-ldt4wizz/numpy_aa6fe1d226f84e6bb986f44165aa0ae6/numpy/distutils/__init__.py", line 8, in <module>
#                 from . import ccompiler
#               File "/tmp/pip-install-ldt4wizz/numpy_aa6fe1d226f84e6bb986f44165aa0ae6/numpy/distutils/ccompiler.py", line 17, in <module>
#                 from numpy.distutils import log
#               File "/tmp/pip-install-ldt4wizz/numpy_aa6fe1d226f84e6bb986f44165aa0ae6/numpy/distutils/log.py", line 13, in <module>
#                 from numpy.distutils.misc_util import (red_text, default_text, cyan_text,
#               File "/tmp/pip-install-ldt4wizz/numpy_aa6fe1d226f84e6bb986f44165aa0ae6/numpy/distutils/misc_util.py", line 15, in <module>
#                 from distutils.msvccompiler import get_build_architecture
#             ModuleNotFoundError: No module named 'distutils.msvccompiler'
#             [end of output]
#
#         note: This error originates from a subprocess, and is likely not a problem with pip.
#       error: metadata-generation-failed
#
#       × Encountered error while generating package metadata.
#       ╰─> See above for output.
#
#       note: This is an issue with the package mentioned above, not pip.
#       hint: See above for details.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
import os
import json
from dotenv import load_dotenv
import PyPDF2
import boto3

# Carregar variáveis de ambiente do arquivo .env
load_dotenv()

# Configuração do cliente Bedrock
class Settings:
    llm = boto3.client(
        'bedrock',
        region_name=os.getenv('AWS_REGION'),
        aws_access_key_id=os.getenv('AWS_ACCESS_KEY'),
        aws_secret_access_key=os.getenv('AWS_SECRET_KEY')
    )

def extrair_texto_pdf(pdf_path):
    """Extrai o texto de um arquivo PDF."""
    with open(pdf_path, 'rb') as file:
        reader = PyPDF2.PdfReader(file)
        texto = ""
        for page in reader.pages:
            texto += page.extract_text() + "\n"
    return texto.strip()

def gerar_quiz_a_partir_pdf(pdf_content):
    """Gera um quiz a partir do conteúdo do PDF usando Bedrock."""
    prompt = (
        "Baseado no seguinte conteúdo de PDF, crie um quiz com 5 perguntas de múltipla escolha, "
        "cada uma com 4 opções de resposta. Inclua a resposta correta para cada pergunta:\n\n"
        f"{pdf_content}\n\n"
        "Formato de resposta: JSON."
    )

    try:
        response = Settings.invoke_model_with_response_stream(
            EndpointName='meta.llama3-1-70b-instruct-v1:0',
            Body=json.dumps({"prompt": prompt, "maxTokens": 300, "temperature": 0.1}),
            ContentType='application/json'
        )
        
        return json.loads(response['Body'].read())  # Retorna a resposta como dicionário
    except Exception as e:
        print(f"Ocorreu um erro: {e}")
        return None

def main():
    # Caminho para o arquivo PDF
    pdf_path = "pdf.pdf"  # Substitua pelo caminho do seu PDF
    
    # Extrair o conteúdo do PDF
    pdf_content = extrair_texto_pdf(pdf_path)
    
    # Gerar o quiz
    quiz = gerar_quiz_a_partir_pdf(pdf_content)
    
    if quiz:
        print("Quiz gerado:", json.dumps(quiz, indent=2))

if __name__ == "__main__":
    main()
# Out:
# Ocorreu um erro: 'Endpoint' object is not callable
